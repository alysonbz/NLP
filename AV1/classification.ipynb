# %%
# %pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: gpg 1.22.0-unknown has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

from vectorizer import count_vectorizer, tf_idf
from preprocessing import create_balanced_sample, PreprocessReviews, filter_vocabulary
# Out:
# [nltk_data] Downloading package stopwords to /home/bbmq/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset_movies = pl.read_csv("/home/bbmq/python_projetos/ambiente/NLP/unidade1/dataset/utlc_movies.csv")

# %%
dataset_movies = dataset_movies.drop(['review_text_processed', 'review_text_tokenized', 'kfold_polarity', 'kfold_rating'])

# %%
dataset_movies = dataset_movies.drop_nulls()

# %%
dataset_movies = dataset_movies.with_columns(
    pl.when(pl.col("polarity") == 0.0)
    .then("negative")
    .otherwise("positive")
    .alias("polarity_label")
)
# Out:
# /tmp/ipykernel_23324/3186190983.py:3: DeprecationWarning: in a future version, string input will be parsed as a column name rather than a string literal. To silence this warning, pass the input as an expression instead: `pl.lit('negative')`
#   .then("negative")
# /tmp/ipykernel_23324/3186190983.py:4: DeprecationWarning: in a future version, string input will be parsed as a column name rather than a string literal. To silence this warning, pass the input as an expression instead: `pl.lit('positive')`
#   .otherwise("positive")

# %%
sample_size_per_class = 50000
balanced_sample = create_balanced_sample(dataset_movies, 'polarity_label', sample_size_per_class)

# %%
preprocessor = PreprocessReviews()

# %%
df_no_stopwords = preprocessor.remove_stopwords(balanced_sample, "review_text")
df_no_stopwords.head
# Out:
# thread '<unnamed>' panicked at py-polars/src/map/series.rs:219:19:
# python function failed KeyboardInterrupt:
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# --- PyO3 is resuming a panic after fetching a PanicException from Python. ---
# Python stack trace below:
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/polars/expr/expr.py:4239, in Expr.map_elements.<locals>.wrap_f(x)
#    4237 with warnings.catch_warnings():
#    4238     warnings.simplefilter("ignore", PolarsInefficientMapWarning)
# -> 4239     return x.map_elements(
#    4240         function, return_dtype=return_dtype, skip_nulls=skip_nulls
#    4241     )
#
# File ~/.local/lib/python3.10/site-packages/polars/series/series.py:5113, in Series.map_elements(self, function, return_dtype, skip_nulls)
# ...

# %%
df_processed = preprocessor.lowercase_remove_punctuation_and_accentuation(df_lematize, "review_text_no_stopwords")

# %%
df_processed = filter_vocabulary(df_processed, "review_text_no_stopwords_cleaned")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_processed = filter_vocabulary(df_processed, "review_text_no_stopwords_cleaned")
#
# NameError: name 'filter_vocabulary' is not defined

# %%
df_processed.head
# Out:
# <bound method DataFrame.head of shape: (100_000, 8)
# ┌─────────────┬────────────┬──────────┬────────┬────────────┬────────────┬────────────┬────────────┐
# │ original_in ┆ review_tex ┆ polarity ┆ rating ┆ polarity_l ┆ review_tex ┆ review_tex ┆ review_tex │
# │ dex         ┆ t          ┆ ---      ┆ ---    ┆ abel       ┆ t_no_stopw ┆ t_no_stopw ┆ t_no_stopw │
# │ ---         ┆ ---        ┆ f64      ┆ i64    ┆ ---        ┆ ords       ┆ ords_lemma ┆ ords_clean │
# │ i64         ┆ str        ┆          ┆        ┆ str        ┆ ---        ┆ ti…        ┆ ed         │
# │             ┆            ┆          ┆        ┆            ┆ str        ┆ ---        ┆ ---        │
# │             ┆            ┆          ┆        ┆            ┆            ┆ str        ┆ str        │
# ╞═════════════╪════════════╪══════════╪════════╪════════════╪════════════╪════════════╪════════════╡
# │ 1380762     ┆ Muito bom! ┆ 1.0      ┆ 5      ┆ positive   ┆ ! Gostei   ┆ ! Gostei   ┆  gostei    │
# ...

# %%
df_lematize = preprocessor.lemmatize_text(df_lematize, "review_text_no_stopwords_cleaned")
# Out:
# thread '<unnamed>' panicked at py-polars/src/map/series.rs:219:19:
# python function failed KeyboardInterrupt:
# --- PyO3 is resuming a panic after fetching a PanicException from Python. ---
# Python stack trace below:
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/polars/expr/expr.py:4239, in Expr.map_elements.<locals>.wrap_f(x)
#    4237 with warnings.catch_warnings():
#    4238     warnings.simplefilter("ignore", PolarsInefficientMapWarning)
# -> 4239     return x.map_elements(
#    4240         function, return_dtype=return_dtype, skip_nulls=skip_nulls
#    4241     )
#
# File ~/.local/lib/python3.10/site-packages/polars/series/series.py:5113, in Series.map_elements(self, function, return_dtype, skip_nulls)
#    5109     pl_return_dtype = py_type_to_dtype(return_dtype)
# ...

# %%
df_lematize.head
# Out:
# <bound method DataFrame.head of shape: (100_000, 9)
# ┌────────────┬────────────┬──────────┬────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ original_i ┆ review_tex ┆ polarity ┆ rating ┆ … ┆ review_tex ┆ review_te ┆ review_te ┆ review_te │
# │ ndex       ┆ t          ┆ ---      ┆ ---    ┆   ┆ t_no_stopw ┆ xt_no_sto ┆ xt_no_sto ┆ xt_no_sto │
# │ ---        ┆ ---        ┆ f64      ┆ i64    ┆   ┆ ords       ┆ pwords_le ┆ pwords_cl ┆ pwords_cl │
# │ i64        ┆ str        ┆          ┆        ┆   ┆ ---        ┆ mmati…    ┆ eaned     ┆ eaned…    │
# │            ┆            ┆          ┆        ┆   ┆ str        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆          ┆        ┆   ┆            ┆ str       ┆ str       ┆ str       │
# ╞════════════╪════════════╪══════════╪════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1380762    ┆ Muito bom! ┆ 1.0      ┆ 5      ┆ … ┆ ! Gostei   ┆ ! Gostei  ┆  gostei   ┆   gostar  │
# ...

# %%
df_processed_tokens = preprocessor.tokenize_text(df_lematize, "review_text_no_stopwords_cleaned_lemmatized")

# %%
df_processed_tokens.head
# Out:
# <bound method DataFrame.head of shape: (100_000, 10)
# ┌────────────┬────────────┬──────────┬────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ original_i ┆ review_tex ┆ polarity ┆ rating ┆ … ┆ review_tex ┆ review_te ┆ review_te ┆ review_te │
# │ ndex       ┆ t          ┆ ---      ┆ ---    ┆   ┆ t_no_stopw ┆ xt_no_sto ┆ xt_no_sto ┆ xt_no_sto │
# │ ---        ┆ ---        ┆ f64      ┆ i64    ┆   ┆ ords_lemma ┆ pwords_cl ┆ pwords_cl ┆ pwords_cl │
# │ i64        ┆ str        ┆          ┆        ┆   ┆ ti…        ┆ eaned     ┆ eaned…    ┆ eaned…    │
# │            ┆            ┆          ┆        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆          ┆        ┆   ┆ str        ┆ str       ┆ str       ┆ list[str] │
# ╞════════════╪════════════╪══════════╪════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1380762    ┆ Muito bom! ┆ 1.0      ┆ 5      ┆ … ┆ ! Gostei   ┆  gostei   ┆   gostar  ┆ ["gostar" │
# ...

# %%
df_processed_tokens.columns
# Out:
# ['original_index',
#  'review_text',
#  'polarity',
#  'rating',
#  'polarity_label',
#  'review_text_no_stopwords',
#  'review_text_no_stopwords_lemmatized',
#  'review_text_no_stopwords_cleaned',
#  'review_text_no_stopwords_cleaned_lemmatized',
#  'review_text_no_stopwords_cleaned_lemmatized_tokens']

# %%
df_tfidf = count_vectorizer(df_processed_tokens, "review_text_no_stopwords_cleaned_lemmatized_tokens")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_tfidf = count_vectorizer(df_processed_tokens, "review_text_no_stopwords_cleaned_lemmatized_tokens")
#
# File ~/python_projetos/ambiente/NLP/AV1/vectorizer.py:14, in count_vectorizer(df, text_column)
#      11             vocabulary[token] = len(vocabulary)
#      13 # Construção da matriz de contagem
# ---> 14 matrix = np.zeros((len(df), len(vocabulary)))
#      15 for i, tokens in enumerate(df[text_column]):
#      16     for token in tokens:
#
# MemoryError: Unable to allocate 56.7 GiB for an array with shape (100000, 76159) and data type float64
