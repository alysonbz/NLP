# %% [markdown]
# **Diferença entre Stemming e Lematização**
#
# Stemming e lematização são técnicas utilizadas em processamento de linguagem natural (NLP) para reduzir palavras a suas formas base ou raízes, mas elas operam de maneiras diferentes e têm finalidades distintas.
#
# **Stemming**
#
# O stemming é um processo que corta os sufixos das palavras para reduzir variantes flexionais a uma raiz comum. Esta técnica é baseada em regras heurísticas simples, sem levar em conta o contexto ou o significado da palavra. O objetivo é transformar diferentes formas de uma palavra em uma base comum para fins de análise textual.
#
# Exemplo:
#
# "amando", "amará", "amado" -> "am"
# "escolas", "escolar", "escolinha" -> "escol"
# O stemming pode resultar em raízes que não são palavras válidas no idioma, como "am" para as diferentes formas da palavra "amar".
#
# Vantagens do Stemming:
#
# Simplicidade e velocidade de execução.
# Reduz variações de palavras a uma forma comum, o que pode ser útil para algoritmos que se beneficiam de uma redução na diversidade de palavras.
#
# Desvantagens do Stemming:
#
# Pode produzir resultados que não são palavras válidas.
# Não leva em conta o contexto ou o significado das palavras.
# Pode ser menos preciso do que a lematização.
#
# -------------------------------------------------------------------------------------
#
# **Lematização**
#
#
# A lematização é um processo mais sofisticado que considera o contexto e a análise morfológica para reduzir uma palavra à sua forma base ou "lema". Diferente do stemming, a lematização utiliza um dicionário para garantir que a forma reduzida é uma palavra válida no idioma.
#
# Exemplo:
#
# "amando", "amará", "amado" -> "amar"
# "escolas", "escolar", "escolinha" -> "escola"
# A lematização produz formas base que são palavras reais e têm significado, considerando o contexto em que são usadas.
#
# Vantagens da Lematização:
#
# Produz palavras válidas e significativas.
# Leva em conta o contexto e o significado das palavras.
# É mais precisa e útil para aplicações que necessitam de compreensão semântica.
# Desvantagens da Lematização:
#
# Pode ser mais lenta e complexa devido à necessidade de análise morfológica e consulta a dicionários.
# Requer modelos e recursos linguísticos mais completos.

# %%
# !pip install spacy
# !pip install nltk
# !python -m spacy download pt_core_news_sm
# !pip install language-tool-python
# Out:
# Requirement already satisfied: spacy in c:\users\joaod\anaconda3\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\joaod\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\joaod\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\joaod\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\joaod\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\joaod\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\joaod\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joaod\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: nltk in c:\users\joaod\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\joaod\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\joaod\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\joaod\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\joaod\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\joaod\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0
MB/s eta 0:00:02
#      ----------------------------- ---------- 9.6/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------ --------- 9.7/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------ --------- 9.9/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------ --------- 9.9/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.1/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/13.0 MB 2.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.3/13.0 MB 2.6 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/13.0 MB 2.6 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/13.0 MB 2.6 MB/s eta 0:00:01
#      -------------------------------- ------- 10.7/13.0 MB 2.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/13.0 MB 2.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.9/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.2/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.3/13.0 MB 2.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.5/13.0 MB 2.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.6/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------ --- 11.9/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------ --- 12.0/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/13.0 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------- -- 12.3/13.0 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/13.0 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/13.0 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------- - 12.6/13.0 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  12.8/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------  12.9/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------  13.0/13.0 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 13.0/13.0 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\joaod\anaconda3\lib\site-packages (from pt-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\joaod\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\joaod\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\joaod\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\joaod\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\joaod\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\joaod\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\joaod\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joaod\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# Collecting language-tool-python
#   Obtaining dependency information for language-tool-python from https://files.pythonhosted.org/packages/d2/82/feb4f01e269267021f1e3a3bb87ad60b201d3fa36dfe9fb85684c025f43a/language_tool_python-2.8-py3-none-any.whl.metadata
#   Downloading language_tool_python-2.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pip in c:\users\joaod\anaconda3\lib\site-packages (from language-tool-python) (23.2.1)
# Requirement already satisfied: requests in c:\users\joaod\anaconda3\lib\site-packages (from language-tool-python) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\joaod\anaconda3\lib\site-packages (from language-tool-python) (4.65.0)
# Requirement already satisfied: wheel in c:\users\joaod\anaconda3\lib\site-packages (from language-tool-python) (0.38.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaod\anaconda3\lib\site-packages (from requests->language-tool-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaod\anaconda3\lib\site-packages (from requests->language-tool-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaod\anaconda3\lib\site-packages (from requests->language-tool-python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaod\anaconda3\lib\site-packages (from requests->language-tool-python) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\joaod\anaconda3\lib\site-packages (from tqdm->language-tool-python) (0.4.6)
# Downloading language_tool_python-2.8-py3-none-any.whl (35 kB)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-2.8

# %%
import spacy
from spacy.lang.pt.stop_words import STOP_WORDS
from string import punctuation
import pandas as pd
import nltk
from nltk.stem import RSLPStemmer
import language_tool_python

nltk.download('rslp')

# Carregar o modelo spaCy para português
nlp = spacy.load('pt_core_news_sm')

# Inicializar o stemmer do NLTK
stemmer = RSLPStemmer()

# Inicializar o LanguageTool para correção gramatical em português
tool = language_tool_python.LanguageTool('pt-BR')

# Função para corrigir o texto usando LanguageTool
def corrigir_texto_automaticamente(texto):
    matches = tool.check(texto)
    texto_corrigido = language_tool_python.utils.correct(texto, matches)
    return texto_corrigido

# Texto com erros gramaticais
texto_com_erros = "Eu vai para a escola ontem. Os menino estava brincando."

# Correção gramatical
texto_corrigido = corrigir_texto_automaticamente(texto_com_erros)

# Processar o texto corrigido com spaCy
doc = nlp(texto_corrigido)

# Tokenização
tokens = [token.text for token in doc]

# Remoção de stop words e pontuação
tokens_sem_stopwords = [token for token in tokens if token.lower() not in STOP_WORDS and token not in punctuation]

# Stemming e Lematização
tokens_stemming = [stemmer.stem(token) for token in tokens_sem_stopwords]
tokens_lematizados = [token.lemma_ for token in doc if token.text in tokens_sem_stopwords]

# Criar a tabela
data = {
    'Token': tokens_sem_stopwords,
    'Stemming': tokens_stemming,
    'Lematização': tokens_lematizados
}

df = pd.DataFrame(data)

# Exibir resultados
print("Texto com Erros:", texto_com_erros)
print("Texto Corrigido:", texto_corrigido)
print("\nTabela de Tokens, Stemming e Lematização:")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 16
#      13 stemmer = RSLPStemmer()
#      15 # Inicializar o LanguageTool para correção gramatical em português
# ---> 16 tool = language_tool_python.LanguageTool('pt-BR')
#      18 # Função para corrigir o texto usando LanguageTool
#      19 def corrigir_texto_automaticamente(texto):
#
# File c:\Users\joaod\anaconda3\Lib\site-packages\language_tool_python\server.py:70, in LanguageTool.__init__(self, language, motherTongue, remote_server, newSpellings, new_spellings_persist, host, config, language_tool_download_version)
#      68     self._update_remote_server_config(self._url)
#      69 elif not self._server_is_alive():
# ---> 70     self._start_server_on_free_port()
#      71 if language is None:
#      72     try:
#
# File c:\Users\joaod\anaconda3\Lib\site-packages\language_tool_python\server.py:270, in LanguageTool._start_server_on_free_port(self)
#     268 self._url = 'http://{}:{}/v2/'.format(self._host, self._port)
#     269 try:
# --> 270     self._start_local_server()
#     271     break
#     272 except ServerError:
#
# File c:\Users\joaod\anaconda3\Lib\site-packages\language_tool_python\server.py:280, in LanguageTool._start_local_server(self)
#     278 def _start_local_server(self):
#     279     # Before starting local server, download language tool if needed.
# --> 280     download_lt(self.language_tool_download_version)
#     281     err = None
#     282     try:
#
# File c:\Users\joaod\anaconda3\Lib\site-packages\language_tool_python\download_lt.py:152, in download_lt(language_tool_version)
#     151 def download_lt(language_tool_version: Optional[str] = LTP_DOWNLOAD_VERSION):
# --> 152     confirm_java_compatibility()
#     154     download_folder = get_language_tool_download_path()
#     156     # Use the env var to the jar directory if it is defined
#     157     # otherwise look in the download directory
#
# File c:\Users\joaod\anaconda3\Lib\site-packages\language_tool_python\download_lt.py:79, in confirm_java_compatibility()
#      77 java_path = find_executable('java')
#      78 if not java_path:
# ---> 79     raise ModuleNotFoundError(
#      80         'No java install detected. '
#      81         'Please install java to use language-tool-python.'
#      82     )
#      84 output = subprocess.check_output([java_path, '-version'],
#      85                                  stderr=subprocess.STDOUT,
#      86                                  universal_newlines=True)
#      88 major_version, minor_version = parse_java_version(output)
#
# ModuleNotFoundError: No java install detected. Please install java to use language-tool-python.
