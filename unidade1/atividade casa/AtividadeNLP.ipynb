# %% [markdown]
# # Primeira Parte
# ## Usabilidade da Biblioteca Polyglot em NLP
#
# A Polyglot é uma biblioteca poderosa para análise de texto multilíngue. Bastante util em várias tarefas, como:
#
# - Detecção de idiomas
# - Análises de sentimentos
# - Traduções, entre outros...
#
# ### Vantagens
# Suporte Multilíngue : Funciona com mais de 130 idiomas.
#
# Recursos de PNL Integrados : Inclui detecção de idioma, análise de sentimentos e NER.
#
# Uso Offline : Funciona sem internet após baixar os pacotes de dados.
#
#
# ### Desvantagens
# Instalação complexa : requer várias dependências difíceis de instalação.
#
# Documentação Limitada : Tem menos suporte e documentação que outras bibliotecas de PNL.
#
# Desempenho e Dados : Pode ser lento com grandes volumes de dados e conter dados desatualizados.
#
# Explorando a sua usabilidade no processamento de textos em português:

# %% [markdown]
# ## Instalação e Configuração
# Antes de usar a Polyglot, precisamos instalar algumas dependências.

# %%
# !pip install polyglot
# !pip install pyicu
# !pip install pycld2
# !pip install morfessor
# !polyglot download embeddings2.pt ner2.pt sentiment2.pt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52562 sha256=a31319276bc0b637918dbd3fabc7cd18801bf6a107756b888562a4cc31eecfee
#   Stored in directory: /root/.cache/pip/wheels/aa/92/4a/b172589446ba537db3bdb9a1f2204f27fe71217981c14ac368
# Successfully built polyglot
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyicu: filename=PyICU-2.14-cp310-cp310-linux_x86_64.whl size=1809838 sha256=9f609b9654be0e556fbfa7a7927be6ceecda7e05e6052fbfb80ea9fb53dca69b
#   Stored in directory: /root/.cache/pip/wheels/78/6e/76/17c73021179c06c29d9b108896b9248da0de4f2af93f63d405
# Successfully built pyicu
# ...

# %% [markdown]
# ## Exemplo de Usabilidade: Detecção de Idioma
#
# A Polyglot é capaz de detectar automaticamente o idioma de uma frase. Isso é útil para pré-processamento de dados multilíngues.

# %%
from polyglot.detect import Detector

texto = "Hoje o dia amanheceu lindo"
detector = Detector(texto)
print(f"Idioma detectado: {detector.language.name}")
# Out:
# Idioma detectado: Portuguese

# %% [markdown]
# ## Exemplo de Usabilidade: Análise de Sentimentos
#
# A Polyglot também possui análise de sentimentos em português, indicando polaridade positiva, negativa ou neutra.

# %%
from polyglot.text import Text

texto = "A minha amiga é maravilhosa, mas tem andado muito triste"
doc = Text(texto, hint_language_code='pt')

# Exibindo polaridade de cada palavra
for palavra in doc.words:
    print(f"Palavra: {palavra}, Sentimento: {palavra.polarity}")
# Out:
# Palavra: A, Sentimento: 0
# Palavra: minha, Sentimento: 0
# Palavra: amiga, Sentimento: 0
# Palavra: é, Sentimento: 0
# Palavra: maravilhosa, Sentimento: 1
# Palavra: ,, Sentimento: 0
# Palavra: mas, Sentimento: 0
# Palavra: tem, Sentimento: 0
# Palavra: andado, Sentimento: 0
# Palavra: muito, Sentimento: 1
# Palavra: triste, Sentimento: -1

# %% [markdown]
# A Polyglot é uma biblioteca completa para análise de texto multilíngue. Com ela, podemos:
# - Automatizar tarefas de pré-processamento de dados
# - Analisar sentimentos e sentimentos de clientes em português
# - Identificar entidades nomeadas para análise de conteúdo
#
# **Aplicações:** A Polyglot pode ser usada em sistemas de suporte ao cliente, análise de comentários em redes sociais e muito mais!

# %% [markdown]
# #Segunda Parte
# ### Tabela com resultados da pesquisa sobre os significados das siglas pos tagging que foram calculadas pela spaCy.

# %%
pip install spacy

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 30.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import pandas as pd
from spacy.lang.pt.examples import sentences
from nltk.stem import RSLPStemmer
import nltk

# %%
nlp = spacy.load("pt_core_news_sm")
doc = nlp(sentences[0])
print(doc.text)
for token in doc:
  print(token.text, token.pos_)
# Out:
# Apple está querendo comprar uma startup do Reino Unido por 100 milhões de dólares
# Apple PROPN
# está AUX
# querendo VERB
# comprar VERB
# uma DET
# startup NOUN
# do ADP
# Reino PROPN
# Unido PROPN
# por ADP
# 100 NUM
# milhões NUM
# de ADP
# dólares NOUN

# %%
dados = [(token.text, token.pos_, token.pos_) for token in doc]

df = pd.DataFrame(dados, columns=["Palavra", "POS", "Significado da Sigla POS"])

pos_significado = {
    "PROPN": "Proper Noun (Nome próprio)",
    "AUX": "Auxiliary (Verbo auxiliar)",
    "VERB": "Verb (Verbo)",
    "DET": "Determiner (Determinante)",
    "NOUN": "Noun (Substantivo)",
    "ADP": "Adposition (Preposição)",
    "NUM": "Numeral (Número)"
}

df["Significado da Sigla POS"] = df["POS"].map(pos_significado)

df
# Out:
#      Palavra    POS    Significado da Sigla POS
# 0      Apple  PROPN  Proper Noun (Nome próprio)
# 1       está    AUX  Auxiliary (Verbo auxiliar)
# 2   querendo   VERB                Verb (Verbo)
# 3    comprar   VERB                Verb (Verbo)
# 4        uma    DET   Determiner (Determinante)
# 5    startup   NOUN          Noun (Substantivo)
# 6         do    ADP     Adposition (Preposição)
# 7      Reino  PROPN  Proper Noun (Nome próprio)
# 8      Unido  PROPN  Proper Noun (Nome próprio)
# 9        por    ADP     Adposition (Preposição)
# 10       100    NUM            Numeral (Número)
# 11   milhões    NUM            Numeral (Número)
# 12        de    ADP     Adposition (Preposição)
# 13   dólares   NOUN          Noun (Substantivo)

# %% [markdown]
# Terceira Parte
# ###Implementação para que sua aplicação receba um texto com erros gramaticais em português.

# %%
# !pip install language-tool-python
# !pip install enelvo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 2.8 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234910 sha256=256048ee7b4a3504e4c9f10ef65a4c9127d12dc703e784fdb7d6aaf129fd04bc
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# ...

# %% [markdown]
# Usando a biblioteca Enelvo para corrigir o texto:

# %%
from enelvo.normaliser import Normaliser

norm = Normaliser(tokenizer='readable', capitalize_inis=True,
                  capitalize_pns=True, capitalize_acs=True,
                  sanitize=False)

texto = "oi, como vc ta se sentindo? hj vc se sente melhpr que ontem?"
resposta = norm.normalise(texto)
print(resposta)
# Out:
# Oi , como você está se sentindo ? Hoje você se sente melhor que ontem ?

# %% [markdown]
# Utilizando spacy e nltk para realizar as tarefas dos itens 2, 3 e 4:

# %%
import spacy
import nltk
from nltk.stem import RSLPStemmer

nltk.download('rslp')

doc = nlp(resposta)
stemmer = RSLPStemmer()

data = []

for token in doc:
    if not token.is_stop and token.is_alpha:
        lemma = token.lemma_
        stem = stemmer.stem(token.text)
        data.append([token.text, stem, lemma])

df = pd.DataFrame(data, columns=["Token", "Stemming", "Lematização"])

print("\nTabela de Tokens, Stemming e Lematização:")
print(df)
# Out:
# Tabela de Tokens, Stemming e Lematização:
#       Token Stemming Lematização
# 0        Oi       oi          Oi
# 1  sentindo     sent      sentir
# 2      Hoje      hoj        hoje
# 3     sente     sent      sentir
# 4    melhor   melhor         bom
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
